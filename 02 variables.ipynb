# %% [markdown]
# #### 回顧：程式儲存在哪裡？
# 上週我們在 GitHub Codespaces 中建立了`environment.ipynb`。
#
# #### 一個新問題
#
# 如果關閉 Codespaces，或想讓其他人看到這份 Notebook，該怎麼辦呢？答案是將檔案提交（Commit）到 GitHub Repository。
#
# #### GitHub Repository 是什麼？
#
# 可以把 Repository（儲存庫）想像成雲端資料夾，專門用來儲存：
# - 程式碼
# - Notebook
# - 文件
# - 專案資料
#
# 例如：
# ```text
# MyPythonCourse
#
# ├── environment.ipynb
# ├── hello.py
# └── README.md
# ```
# #### 提交 Notebook 到 Repository
#
# 在 Codespaces 左側的 Source Control 圖示中，如果看到`environment.ipynb U`，其中U表示：Untracked（尚未被 Git 追蹤）。也就是說
# Git 發現了這個檔案，但目前還沒有將它納入版本管理。
#
# #### 如何操作？
#
# 在 Terminal 中輸入：
#
# 將檔案加入追蹤：`git add environment.ipynb`
#
# 建立提交紀錄：`git commit -m "Add environment notebook"`
#
# 將提交上傳到 GitHub Repository：`git push`
#
# 如果學不會，麻煩來上中午的實習課喔
#
# https://github.com/Jerry-ya-ya/Git-tutorial
#
# 或者用CodeSpaces的檔案總管
#
# 1. environment.ipynb 旁邊有個+按下去，會出現暫存的變更，這個動作對應到git add environment.ipynb
# 2. 「變更」標題的下方、綠色按鈕的上方。顯示：訊息（要在 "Ctrl+Enter" 上提交 main），輸入Add environment notebook，此動作對應到git commit -m "Add environment notebook
# 3. 最後後按綠色按鈕：提交，等同於git push
#
# 或者使用 Codespaces（VS Code）的「原始碼控制（Source Control）」介面：
# 1.在 environment.ipynb 旁邊按下 +。檔案會移到「暫存的變更（Staged Changes）」區域。這個動作對應到：git add environment.ipynb
# 2.在「變更」標題下方的訊息框中輸入：Add environment notebook，然後按下「提交（Commit）」按鈕。這個動作對應到：git commit -m "Add environment notebook"
# 3.提交完成後，按下：同步變更（Sync Changes）或Push，這個動作對應到：git push。

# %% [markdown]
# 可以將 VS Code / Codespaces 的操作與 Git 指令對照如下：
# ```
# VS Code / Codespaces
# --------------------------------
# +                     → git add
#
# 提交（Commit）         → git commit
#
# 同步變更（Sync）       → git push
# 因此整個流程可以整理成：
# ```
# 修改檔案
#     ↓
# 按 +
#     ↓
# git add
#
# 輸入 Commit Message
#     ↓
# 按 提交
#     ↓
# git commit
#
# 按 同步變更
#     ↓
# git push
# 例如只想提交：
#
# environment.ipynb
# 則只需要對該檔案按 +，再進行 Commit 與 Sync Changes，其餘檔案不會一起提交。

# %% [markdown]
# 回顧上週9/17，我們在Microsoft Copilot下了以下的prompt：
#
# 已在VS code 建立20260917.ipynb 想在螢幕上show出Hello World!，請問Python程式碼怎麼寫？
#
# AI 回答如下：

# %%
print("Hello Wrold!")
# Out:
# Hello Wrold!

# %% [markdown]
# 好奇的是，當我們按下執行按鈕後，電腦內部究竟發生了什麼事情呢？ 試著想像下面的流程圖：
#
# ```text
# 使用者
#   │
#   │ 鍵盤輸入
#   ▼
# 瀏覽器（Web Browser）
#   │
#   ▼
# Jupyter Notebook
#   │
#   │ 執行程式
#   ▼
# Python Interpreter
#   │
#   │ 執行 print("Hello World!")
#   ▼
# 作業系統（Operating System, Linux）
#   │
#   │ 將文字 "Hello World!"
#   | 傳送至輸出裝置
#   ▼
# 螢幕（Monitor）
# 顯示
# Hello World!
# ```

# %% [markdown]
# #### Python 與 Python Interpreter
#
# 當我們安裝並執行 Python 時，是透過某個 Python Interpreter 來執行 Python 程式。平常我們說Python，其實這個詞有兩種不同的意思。第一個意思是Python 語言（Python Language），它負責定義語法（Syntax）、關鍵字（Keywords）、資料型別（Data Types）、函式的行為、語言規則（Language Rules）。例如
# ```python
# print("Hello World!")
# ```
# 是一段合法的 Python 程式。然而
# ```python
# print("Hello World!"
# ```
# 少了一個右括號，因此不符合 Python 語法。
#
# 這些規則是由 Python 語言本身所定義的。
#
# 第二個意思是Python Interpreter，它是一個真正的程式（Program），負責讀取並執行 Python 程式碼。
#
# 有一門課叫編譯器（Compiler），主要研究如何讓電腦理解程式語言？換句話說
# ```text
# Python Language
#         ↓
# 如何檢查語法？
#
# 如何理解程式的意思？
#
# 如何執行程式？
#
# 如何產生機器碼？
# ```
# 這些問題就是編譯器課程的核心。
#
# 舉例來說，`print("Hello World!")`。編譯器（Compiler）或直譯器（Interpreter）並不會一開始就理解這段程式的意義。相反地，它會逐步分析程式碼。第一層字元（Characters）。首先，程式碼只是一串字元：`p r i n t ( " H e l l o ...`，這些字元是什麼？這些字元本身並沒有太多意義，編譯器必須先將它們組合成更有意義的單位。
#
# 第二層詞元（Tokens）。接著進行詞法分析（Lexical Analysis），將字元組合成詞元（Token）：
# ```text
# print
# (
# "Hello World!"
# )
# ```
# 其中`print`是一個識別字（Identifier）、(和)是括號符號、"Hello World!"是一個字串常值（String Literal）。
#
# 詞法分析的工作就是將字元串轉換成一連串有意義的詞元（Tokens）。
#
# 第三層語法結構（Syntax）。接著進行語法分析（Syntax Analysis）。編譯器會檢查`print("Hello World!")`，是否符合 Python 文法。例如`print("Hello World!"`，缺少右括號。因此產生Syntax Error，因為這段程式不符合 Python 的語法規則。
#
# 第四層語意，理解`print(...)`的意思是，呼叫 print 函式。這稱為語意分析Semantic Analysis。
#
# 第五層：執行。最後顯示 Hello World!
#
# CPython 是Implementation（實作）。編譯器課通常會進一步研究：
# ```text
# Python Language
#         ↓
# CPython 如何實作？
#
# Java Language
#         ↓
# JVM 如何實作？
#
# C Language
#         ↓
# GCC 如何實作？
# ```
#
# 總之，編譯器課程主要研究：「如何讓電腦理解並執行程式語言？」因此其重點通常在於程式語言的規格（Specification）及其實作（Implementation）之間的轉換過程，例如詞法分析、語法分析、語意分析與程式執行。其中：
# - Python Language 屬於規格（Specification）。
# - CPython、PyPy 等屬於規格的實作（Implementation）。

# %% [markdown]
# #### 常見的 Python Interpreter
#
#
# ##### CPython
#
# 最常見的 Python Interpreter。
# - Python 官方實作（Reference Implementation）
# - 使用 C 語言撰寫
# - 幾乎所有 Python 教材預設都是 CPython
# - GitHub Codespaces 通常也是使用 CPython
#
# ```text
# Python 程式
#       ↓
#  CPython
#       ↓
#  作業系統
# ```
# ##### PyPy
#
# 另一種 Python 實作。
#
# - 使用 RPython 撰寫
# - 具有 JIT（Just-In-Time Compilation）功能
# - 某些程式執行速度可能比 CPython 更快
#
# ```text
# Python 程式
#       ↓
#    PyPy
#       ↓
#  JIT 編譯
#       ↓
#  作業系統
# ```
# ##### Jython
#
# Java 平台上的 Python。
#
# - 使用 Java 撰寫
# - 執行於 JVM（Java Virtual Machine）
# - 可直接使用 Java 類別庫
#
# ```text
# Python 程式
#       ↓
#    Jython
#       ↓
#     JVM
#       ↓
#  Java 平台
# ```
# ##### IronPython
#
# .NET 平台上的 Python。
#
# - 使用 C# 實作
# - 執行於 .NET CLR
# - 可使用 .NET 類別庫
#
# ```text
# Python 程式
#       ↓
#  IronPython
#       ↓
#     CLR
#       ↓
#  .NET 平台
# ```
# ##### MicroPython
#
# 嵌入式系統版本的 Python。
#
# 例如：
#
# - ESP32
# - Raspberry Pi Pico
# - 微控制器
#
# ```text
# Python 程式
#       ↓
#  MicroPython
#       ↓
#  微控制器
# ```
# 常見於 IoT 與嵌入式開發

# %% [markdown]
# | Interpreter | 主要實作語言 |
# |------------|------------|
# | CPython | C |
# | PyPy | RPython |
# | Jython | Java |
# | IronPython | C# (.NET) |
# | MicroPython | C |
#
# #### 課堂練習
# 1. 在本課程的 GitHub Codespaces 中，通常使用哪一種 Python Interpreter？
# -------------通常使用的是 CPython。當你在 GitHub Codespaces 或一般電腦上安裝官方 Python 時，預設使用的就是 CPython。
# 2. CPython 是用什麼語言撰寫的？
# -------------CPython 的名稱中的「C」就是因為它主要是使用 C 語言開發的。
# 3. PyPy 與 CPython 的主要差異是什麼？
# -------------CPython：官方標準 Python Interpreter，相容性最好，最廣泛使用。
# PyPy：另一種 Python Interpreter，具有 JIT（Just-In-Time）編譯器，許多程式執行速度比 CPython 更快。
# 4. 為什麼 Python 語言可以有多種不同的 Interpreter？
# -------------因為 Python 是一種程式語言規格（Language Specification），只要遵守 Python 的語法與規則，就能開發不同的 Interpreter。

# %% [markdown]
# #### 如何知道 Interpreter 存在？
#
# 在 Terminal 中執行：`python --version`，可能看到`Python 3.13.7`，表示目前使用的 Python Interpreter 版本。
# 也可以執行`which python`查看 Python Interpreter 的位置。
#
# #### 課堂練習
#
# 1. 為什麼電腦不能直接執行 Python 程式碼？
# 2. Python Interpreter 的主要功能是什麼？
# 3. 在下列流程中，誰負責執行 Python 程式？
# ```text
# Jupyter Notebook
#     ↓
# Python Interpreter
#     ↓
# 作業系統
#     ↓
# 螢幕
# ```
# 4. 如果沒有 Python Interpreter，下面的程式能否執行？
# ```python
# print("Hello World!")
# ```

# %% [markdown]
# 當我們在 Jupyter Notebook 中輸入：
#
# ```python
# print("Hello World!")
# ```
#
# 並按下執行按鈕（Run）時，電腦內部大致會發生下列事情：
#
# 1. Jupyter Notebook 將程式碼送給 Python Interpreter。
# 2. Python Interpreter 讀取並理解程式碼。
# 3. Interpreter 執行：
#
#    ```python
#    print("Hello World!")
#    ```
#
# 4. `print()` 要求作業系統顯示文字：
#
#    ```text
#    Hello World!
#    ```
#
# 5. 作業系統將結果傳送到輸出裝置。
# 6. 在 Jupyter Notebook 中，結果顯示於程式儲存格（Code Cell）下方的輸出區域（Output Area）。
#
# 因此畫面看到：
#
# ```text
# Hello World!
# ```
#
# ---
#
# #### 程式執行流程
#
# ```text
# 鍵盤
#   │
#   │ 輸入程式碼
#   ▼
#
# print("Hello World!")
#
#   │
#   │ 按下 Run
#   ▼
#
# Jupyter Notebook
#
#   │
#   ▼
#
# Python Interpreter
#
#   │
#   │ 執行 print()
#   ▼
#
# 作業系統
#
#   │
#   │ 顯示文字
#   ▼
#
# Output Area
#
#   │
#   ▼
#
# Hello World!
# ```
#
# ---
#
# #### Input-Process-Output（IPO）模型
#
# 其實，上面的程式執行過程也隱含了資訊處理常見的 IPO 模型：
#
# ```text
# Input（輸入）
#       ↓
# 鍵盤輸入程式碼
#
# Process（處理）
#       ↓
# Python Interpreter 執行程式
#
# Output（輸出）
#       ↓
# 螢幕顯示 Hello World!
# ```
#
# ---
#
# #### 課堂練習
#
# 在上述 IPO 模型中：
#
# ```python
# print("Hello World!")
# ```
#
# 請指出：
#
# 1. 哪個部分屬於 Input（輸入）？
# ---------------沒有輸入（Input）
# 因為程式沒有使用 input() 讓使用者輸入資料。
# 2. 哪個部分屬於 Process（處理）？
# ---------------print() 指令
# 程式執行 print() 函式來處理顯示文字的工作。
# 3. 哪個部分屬於 Output（輸出）？
# ---------------Hello World!
# 4. 如果將程式改為
#
#    ```python
#    print("Python")
#    ```
#
#    IPO 模型中的哪個部分會改變？
#    ------------改成 print("Python") 後，Output（輸出）改變，變成 Python。

# %% [markdown]
# #### 那麼 "Hello World!" 是從哪裡來的？
#
# 我們看到：
# ```python
# print("Hello World!")
# ```
# 時，可能會想：「Hello World! 到底是誰放進去的？」答案其實很簡單：是程式設計師（也就是你）輸入的。
#
# 例如在鍵盤上輸入：
# ```python
# print("Hello World!")
# ```
# 其中：
# ```python
# "Hello World!"
# ```
# 是我們想要顯示的文字內容。
#
# 例如：
# ```python
# print("Python")
# ```
# 輸出：
# ```text
# Python
# ```
# ```python
# print("I love AI")
# ```
# 輸出：
# ```text
# I love AI
# ```
# 因此可以這樣理解：
# ```text
# print()
#     ↓
# 負責顯示資料
#
# "Hello World!"
#     ↓
# 要被顯示的資料
# ```

# %% [markdown]
# #### 在不同環境中的輸出位置
# `print()` 的功能是將資料輸出到標準輸出（Standard Output）。
# 不同執行環境中，輸出的位置可能不同：
# ```text
# Jupyter Notebook
#       ↓
# Code Cell 下方的 Output Area
#
# Terminal
#       ↓
# 終端機視窗
#
#
# Command Prompt
#         ↓
# 主控台視窗
# ```
# 因此：
#
# ```python
# print("Hello World!")
# ```
# 在不同環境中產生的結果相同：
#
# ```text
# Hello World!
# ```
# 只是顯示的位置不同。

# %% [markdown]
# #### 課堂練習
#
# 請依序執行下列程式：
#
# ```python
# print("Hello World!")
# ```
#
# ```python
# print("Python")
# ```
#
# ```python
# print("I am learning Python.")
# ```
#
# 再執行：
#
# ```python
# print('Hello World!')
# ```
#
# ```python
# print('Python')
# ```
#
# ---
#
# #### 觀察與思考
#
# 1. `print()` 的功能是什麼？
#
#    ----------------將資料或文字顯示在螢幕上（輸出）
#
# 2. 雙引號中的文字是由誰提供的？
#
#    ----------------雙引號中的文字：由程式設計者提供。
#
# 3. 按下 Run 之後，哪一個程式負責執行 Python 程式碼？
#
#    ----------------執行程式碼：Python 解譯器。
#
# 4. 為什麼結果會顯示在 Code Cell 下方？
#
#   ----------------結果顯示在 Cell 下方：因為輸出會顯示在標準輸出區域。
#
# 5. 下列兩種寫法的執行結果是否相同？
#
# ```python
# print("Hello World!")
# ```
#
# ```python
# print('Hello World!')
# ```
#
# 說明原因。
#
# ------------------兩者結果相同，因為單引號與雙引號都能表示字串。
#
# 6. 什麼是標準輸出（Standard Output）？
#
#    --------------標準輸出：程式預設顯示結果的地方（通常是螢幕）
#
# #### 延伸實驗：標準輸入與標準輸出
#
# 執行下列程式：
#
# ```python
# name = input("What is your name? ")
#
# print("Hello,", name)
# ```
#
# 請輸入你的名字，例如：
#
# ```text
# Jack
# ```
#
# 觀察輸出結果。
#
# ---
#
# #### 思考問題
#
# 1. 在上述程式中，資料是從哪裡輸入的？
#
#   -----------鍵盤輸入。
#
# 2. `input()` 的功能是什麼？
#
#    ----------接收使用者輸入資料。
#
# 3. `print()` 的功能是什麼？
#
#    ----------將資料顯示在螢幕上。
#
# 4. 下列哪些屬於輸入（Input）？
#
# - 鍵盤輸入
# - 滑鼠點擊
# - 麥克風錄音
# - 攝影機拍攝
#
# -----------聲音輸入、滑鼠點擊、麥克風錄音。
#
# 5. 下列哪些屬於輸出（Output）？
#
# - 螢幕顯示
# - 喇叭播放聲音
# - 印表機列印
# - LED 燈亮起
#
# ------------螢幕顯示、喇叭播放聲音、LED燈亮起。
#
# ---
#
# #### Input-Process-Output（IPO）模型
#
# 請根據下列程式：
#
# ```python
# name = input("What is your name? ")
#
# print("Hello,", name)
# ```
#
# 完成下表：
#
# Input（輸入）
#
# -----------使用者輸入姓名
#
# Process（處理）
#
# ----------將姓名存入 name 並組合成問候語
#
# Output（輸出）
#
# ----------Hello, Jack（或其他輸入的姓名）

# %% [markdown]
# #### `print()` 的結果只能顯示在螢幕上嗎？
#
# 初學者常認為：
# ```python
# print("Hello World!")
# ```
# 一定會在螢幕上顯示：
#
# ```text
# Hello World!
# ```
# 但更精確地說：
#
# ```python
# print()
# ```
# 的功能是將資料輸出到：
#
# ```text
# 標準輸出（Standard Output）
# ```
# 通常簡寫為：
#
# ```text
# stdout
# ```
# ---
#
# #### 不同環境中的標準輸出
#
# 同樣的程式：
#
# ```python
# print("Hello World!")
# ```
# 在不同執行環境中，
# 標準輸出可能對應到不同地方。
# ##### Jupyter Notebook
# ```text
# stdout
#     ↓
# Output Area
# ```
# 因此結果顯示在儲存格下方：
# ```text
# Hello World!
# ```
# ##### Terminal
#
# 如果執行：
#
# ```bash
# python hello.py
# ```
# 則：
# ```text
# stdout
#     ↓
# Terminal
# ```
# 結果顯示在終端機視窗中：
#
# ```text
# Hello World!
# ```
# ##### 重新導向到檔案
#
# 在 Linux 中：
#
# ```bash
# python hello.py > output.txt
# ```
# 此時：
#
# ```text
# stdout
#     ↓
# output.txt
# ```
# 結果不會顯示在螢幕上，而是寫入：
# ```text
# output.txt
# ```
# 內容：
#
# ```text
# Hello World!
# ```
# #### Input-Process-Output（IPO）
#
# 因此：
#
# ```python
# print("Hello World!")
# ```
# 比較精確的流程應該是：
#
# ```text
# Input
#     ↓
# 程式中的資料
#
# "Hello World!"
#
# Process
#     ↓
# Python Interpreter 執行 print()
#
# Output
#     ↓
# 標準輸出（stdout）
# ```
# 而：
#
# ```text
# Jupyter Output Area
# Terminal
# 檔案
# ```
# 都是標準輸出的不同呈現方式。

# %% [markdown]
# #### 課堂練習
#
# 問AI，是否可以提供print('Hello World!') 輸出在Flask Web 的Python程式碼?
# ---------------不可以。

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def hello():
    return "Hello World!"

if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [18/Sep/2026 15:06:00] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Sep/2026 15:06:00] "GET /favicon.ico HTTP/1.1" 404 -

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def hello():
    print("Hello World!")
    return "Hello World!"

app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [18/Sep/2026 15:12:21] "GET / HTTP/1.1" 200 -
# Hello World!

# %% [markdown]
# #### ModuleNotFoundError
# ModuleNotFoundError: No module named 'flask'
#
# Python Interpreter 找不到 Flask 套件。意思是 Flask 尚未安裝到目前的 Python 環境中。
#
# 在 Terminal 輸入：`pip install flask`或`python -m pip install flask`。安裝完成後檢查：`pip show flask`，應該會看到：
# ```
# Name: Flask
# Version: ...
# ```
#
# ### 如果你有使用 venv
#
# 假設前面課程已建立：`python -m venv .venv`，則要先啟動虛擬環境：`source .venv/bin/activate`。
# 看到提示可能變成`(.venv) @Jackpan5678 ➜ /workspaces/115Python (main) $`。
# 之後再安裝：`pip install flask`。
# 因為全域 Python≠虛擬環境 Python。

# %% [markdown]
# ```text
# Browser 請求
#       │
#       ▼
#
# Flask
#
#       │
#       ├── print("Hello World!")
#       │          │
#       │          ▼
#       │      Terminal
#
#       │
#       └── return "Hello World!"
#                  │
#                  ▼
#               Browser
# ```

# %% [markdown]
# #### 資料存放在哪裡？
# 當我們使用鍵盤輸入：
# ```python
# print("Hello World!")
# ```
# 並執行程式時，電腦不會一直記住鍵盤按下的動作。相反地，Python Interpreter 會讀取程式碼中的資料`Hello World!`，並在執行程式時使用記憶體（Memory）來儲存這些資料。我們可以想像成：
# ```text
# 鍵盤
# │
# │ 輸入
# ▼
#
# "Hello World!"
#
# │
# ▼
#
# Python Interpreter
#
# │
# │ 使用記憶體儲存資料
# ▼
#
# 記憶體（Memory）
#
# ┌─────────────┐
# │Hello World! │
# └─────────────┘

# %% [markdown]
# #### 如果希望重複使用資料
# 當我們執行：
# ```python
# print("Hello World!")
# ```
# 時，字串 `"Hello World!"` 會被送給 `print()` 顯示出來。如果之後還想再次使用這筆資料，每次都重新輸入`print("Hello World!")`
# 會有些不方便。因此產生了一個新的問題：電腦要把這筆資料放在哪裡，才能在需要時再次使用呢？
#
# #### 記憶體（Memory）
# 在程式執行期間，資料通常會暫時儲存在記憶體（Memory）中。你可以把記憶體想像成電腦工作時使用的草稿紙或工作桌面。當程式需要資料時，
# 可以從記憶體取出來使用。例如：
# ```text
# 記憶體
# ┌─────────────┐
# │Hello World! │
# └─────────────┘
# ```
#
# #### 變數（Variable）
#
# 如果記憶體中有許多資料，Python 要如何找到其中某一筆資料呢？因此我們可以替資料取一個名稱：
# ```python
# message = "Hello World!"
# ```
# 可以想像成：
# ```text
# 記憶體
# ┌─────────────┐
# │Hello World! │
# └─────────────┘
#        ▲
#        │
#    message
# ```
# 其中：
#
# - `"Hello World!"` 是資料。
# - `message` 是資料的名稱。
#
# 未來如果需要這筆資料，就不必重新輸入`"Hello World!"`，而可以直接使用`message`來存取它。接著`print(message)`，Python 會根據名稱 `message` 找到對應的資料，並顯示`Hello World!`。

# %% [markdown]
# ### 課堂練習
#
# 請比較下列兩段程式：
#
# ```python
# print("Hello World!")
# ```
#
# ```python
# message = "Hello World!"
# print(message)
# ```
#
# 1. 兩段程式的輸出結果是否相同？-----------是，相同。 都輸出 Hello World!。
#
# 2. 第二種寫法為什麼要使用變數？------------使用變數可以儲存資料並重複使用，讓程式更容易維護。
#
# 3. 如果要將 `"Hello World!"` 改成 `"Python Programming"`，哪一種寫法比較容易修改？-------------第二種寫法較容易修改，只需更改變數 message 的內容即可。

# %% [markdown]
# #### 一個值得思考的問題
# 剛剛我們提到`message = "Hello World!"`，可以想像成
# ```text
# 記憶體
#
# ┌─────────────┐
# │Hello World! │
# └─────────────┘
#        ▲
#        │
#    message
# ```
# 此時可能會產生一個問題：資料一定要放在記憶體中嗎？
#
# #### 記憶體與儲存裝置
#
# 事實上，電腦中有不同的儲存空間。例如：`主記憶體（RAM, Random Access Memory）以及固態硬碟（SSD）或硬碟（Hard Disk）。當我們撰寫：
#
# ```python
# message = "Hello World!"
# ```
# 時，這段程式碼最初是儲存在檔案中：`hello.py`或`notebook.ipynb`，而這些檔案通常存放在`SSD 或硬碟`上。當按下執行按鈕後：
# ```text
# 程式檔
#     ↓
# Python Interpreter
#     ↓
# 記憶體（RAM）
#     ↓
# CPU 執行
# ```
# 程式需要使用的資料才會被載入記憶體。因此：`message = "Hello World!"`在程式執行期間，通常可以把它想像成位於記憶體中。
#
# #### 為什麼需要記憶體？
#
# 因為 CPU 執行程式時，必須能快速取得資料。可以把它想像成：
# ```text
# 書櫃（SSD）
#     ↓
# 存放大量資料
#
# 書桌（RAM）
#     ↓
# 目前正在使用的資料
# ```
# 通常會先把要閱讀的書從書櫃拿到書桌上，再開始閱讀。電腦也有類似的運作方式：
# ```text
# SSD
#     ↓
# 載入
#     ↓
# RAM
#     ↓
# CPU 執行
# ```
# 未來學習作業系統與計算機組織時，會深入探討：
#
# - 記憶體（Memory）
# - 快取（Cache）
# - SSD
# - 虛擬記憶體（Virtual Memory）

# %% [markdown]
# #### 陳述式與運算式
# 剛剛我們已經寫過：
# ```python
# message = "Hello World!"
# print(message)
# ```
# 這兩行程式碼可以幫助我們認識 Python 中兩個重要的概念：
# ```text
# 陳述式（Statement）
#
# 運算式（Expression）
# ```
# 在 Python 中，每一行完成一個動作的程式碼，通常稱為一個陳述式（Statement）。例如：
# ```python
# message = "Hello World!"
# ```
# 以及：
# ```python
# print(message)
# ```
# 都是陳述式。
#
# 另一方面，如果一段程式碼可以產生一個值，那麼這段程式碼就稱為運算式（Expression）。例如：
# ```python
# "Hello World!"
# ```
# 是一個運算式。它所代表的值為`Hello World!`。再例如`2 + 3`是一個運算式。其值為5。
#
# 回到剛剛的程式：`message = "Hello World!"`，觀察`"Hello World!"`是運算式（Expression）。它產生的值為Hello World!，而整行`message = "Hello World!"`則是一個陳述式（Statement），其作用是將運算式所得到的值存放到變數 `message` 中。
#
#
# 接著看`print(message)`，其中`message`也是一個運算式。其值為`Hello World!`。而整行`print(message)`則是一個陳述式，其作用是將變數中的內容顯示在畫面上。
# #### 圖解
#
# ```text
# message = "Hello World!"
#
#           │
#           │
#           ▼
#
#       運算式
#    "Hello World!"
#
#           │
#           ▼
#
#       Hello World!
#
#           │
#           ▼
#
#       陳述式
# message = ...
# ```
#
# ---
#
# #### 課堂練習
#
# 請判斷下列程式碼中的運算式與陳述式：
#
# ```python
# score = 90
# ```
#
# ```python
# 2 + 3
# ```
#
# ```python
# print(score)
# ```
#
# ```python
# score + 10
# ```
# 1. 哪些是陳述式（Statement）？----------score = 90 , print(score)
# 2. 哪些是運算式（Expression）？-----------2 + 3 , score + 10
# 3. 哪些運算式會產生值？---------score + 10
# 4. 哪些陳述式會執行動作？----------score = 90      # 儲存資料
#                      ------------print(score)    # 顯示資料

# %% [markdown]
# #### 函式（Function）的概念
# 看到下面的程式：`print("Hello World!")`，是否覺得看起來有點像數學中的$f(x)$，其中：
# - `f` 類比為 `print`
# - `x` 類比為 `"Hello World!"`
# 在數學中，$f(x)$表示把輸入的資料 \(x\) 交給函式 \(f\) 處理。例如$f(x)=x^2$，則$f(3)=9$，可以表示成：
# ```text
# 輸入
#  3
#  │
#  ▼
#  f
#  │
#  ▼
#  9
# ```
# Python 中也有類似的概念`print("Hello World!")`，其中：
# - `print` 是函式名稱（Function Name）。
# - `"Hello World!"` 是提供給函式的資料。
# - 括號 `( )` 用來放入要交給函式處理的資料。
# 可以表示成：
# ```text
# 輸入
# "Hello World!"
#        │
#        ▼
#      print
#        │
#        ▼
# Hello World!
# ```
# 函式可以想像成一台機器：
# ```text
# 資料
#   │
#   ▼
# 函式
#   │
#   ▼
# 結果
# ```
# 例如：`print("Python")`輸出：Python；`print(100)`，輸出：100。因此`print("Hello World!")`可以理解成：將資料 `"Hello World!"` 交給函式 `print` 處理，而 `print` 的工作就是把資料顯示在畫面上。
#
# #### 課堂練習
# 請比較：
#
# ```python
# print("Python")
# ```
#
# ```python
# print(100)
# ```
#
# ```python
# print(True)
# ```
#
# 1. 哪一部分是函式名稱？--------------函式名稱：print
# 2. 哪一部分是提供給函式的資料？-------提供給函式的資料："Python"、100、True
# 3. `print()` 的工作是什麼？----------print() 的工作：將資料輸出到螢幕
# 4. 如果改成：
#
# ```python
# print("AI")
# ```
#
# 畫面會顯示什麼？---------print("AI") 的輸出結果：

# %% [markdown]
# #### 思考問題
# 請比較下列程式：
# ```python
# message = "Python"
# print(message)
# ```
# 執行結果：
# ```text
# Python
# ```
# ```python
# message = 100
# print(message)
# ```
# 執行結果：
# ```text
# 100
# ```
# ```python
# message = True
# print(message)
# ```
# 執行結果：
# ```text
# True
# ```
# #### 觀察
# 在上述三個程式中：`message`都是同一個變數名稱。但是：`message = "Python"`中的資料是文字、`message = 100`中的資料是整數、`message = True`中的資料是布林值（Boolean）。
#
# #### 一個值得思考的問題
#
# 為什麼同一個變數：`message`，有時候可以存放文字，有時候又可以存放數字？
#
# #### Python 的做法
# 在 Python 中，變數就像資料的名稱。
# ```text
# message
#     ↓
# "Python"
# ```
# 或
# ```text
# message
#     ↓
# 100
# ```
# 因此：變數本身不需要先宣告資料型別。Python 會根據資料內容，自動判斷資料型別。這種方式稱為動態型別（Dynamic Typing）
#
# #### 與 C 語言比較
#
# 在 C 語言中，通常必須先宣告資料型別：
#
# ```c
# int message = 100;
# ```
# 表示：
# ```text
# message 是整數變數
# ```
# 若要存放文字：
# ```c
# char message[] = "Python";
# ```
# 則需要重新使用另一種型別。
#
# 因此在 C 語言中：
# ```text
# 變數
#     │
#     ▼
# 型別固定
# ```
# 這種方式稱為靜態型別（Static Typing）。

# %% [markdown]
# #### 如何觀察變數?
#
# 1. 在視窗中，找到`Jupyter變數`，如果新增加的檔案，類似於Untitled-1.ipyb，先save，就會看到`Jupyter變數`。
#
# 2. 開啟Jupyter變數檢視
#
# 例如下圖顯示：
# ```text
# Jupyter Variables
#
# +--------------------------------------+
# | Name | Type | Size | Value           |
# +--------------------------------------+
# | 未定義任何變數                        |
# +--------------------------------------+
#
# 其中：
# - **Name**：變數名稱（Variable Name）
# - **Type**：資料型別（Data Type）
# - **Size**：資料大小（Size）
# - **Value**：資料內容（Value）
#
# 目前顯示：未定義任何變數，表示目前 Notebook 尚未建立任何變數。例如：`print("Hello World!")`雖然會輸出：Hello World!，
# 但並沒有建立變數，因此 Variables 視窗中仍然顯示：未定義任何變數。若執行：`message = "Hello World!"`，則 Variables 視窗可能顯示：
#
#
#
# ```text
# +--------------------------------------+
# | Name    | Type | Size | Value        |
# +--------------------------------------+
# | message   str    12     Hello World! |
# +--------------------------------------+
# ````
# 其中：
# - **Name**：變數名稱（Variable Name）
# - **Type**：資料型別（Data Type）
# - **Size**：資料大小（Size）
# - **Value**：資料內容（Value）

# %% [markdown]
# #### 使用 VS Code Debugger 觀察變數
# hello.py
# ```python
# message = "Hello World!"
# print(message)
# ```
# 在程式第一行設定中斷點（Breakpoint）`message = "Hello World!"`，按下Ctrl + Shift + D，開啟執行與偵錯 **Run and Debug**，
# 再按：F5（開始與偵錯）。接著按：逐步執行F11。。此時 左邊畫面的Variables 視窗顯示：
# ```text
# Locals
# message = 'Hello World!'
# ```
# 表示：
#
# ```python
# message = "Hello World!"
# ```
# 已經執行完成，變數 `message` 已經存在，而且目前的值（Value）為：Hello World!。再按一次 F11，執行：`print(message)`，
# 畫面就會出現：Hello World!，然後程式結束。

# %% [markdown]
# #### 課堂練習：觀察資料型別
#
# 請依序執行下列程式碼，並利用 **Jupyter Variables** 視窗觀察變數 `message` 的：
# - Type（資料型別）
# - Value（資料內容）
#
# ```python
# message = "Hello World!"
# ```
# ```python
# message = "100"
# ```
# ```python
# message = 100
# ```
# ```python
# message = 100.0
# ```
# ```python
# message = True
# ```
#
# #### 記錄觀察結果
#
# 請完成下表：
#
# | 程式碼 | Type | Value |
# |---------|---------|---------|
# | `message = "Hello World!"` | ? | ? |
# | `message = "100"` | ? | ? |
# | `message = 100` | ? | ? |
# | `message = 100.0` | ? | ? |
# | `message = True` | ? | ? |
#
# ---
#
# #### 思考問題
#
# 1. 下列兩者有何不同？----------------------"100" 是字串（String），100 是整數（Integer）。
#
#    ```python
#    message = "100"
#    ```
#
#    ```python
#    message = 100
#    ```
#
# 2. 為什麼：
#
#    ```python
#    message = "100"
#    ```
#
#    是字串（String），而不是整數（Integer）？----------------因為有引號包住，所以 "100" 被視為字串。
#
# 3. 變數名稱都叫做：
#
#    ```python
#    message
#    ```
#
#    為什麼資料型別（Type）卻可能不同？---------------------message 只是變數名稱，可以儲存不同型態的資料，因此可以放字串、整數或布林值。
#
# 4. Python 如何知道：
#
#    ```python
#    "Hello World!"
#    ```
#
#    應該是字串，
#
#    而：
#
#    ```python
#    100
#    ```
#
#    應該是整數？
#    -------------------Python 透過語法規則判斷資料型態：
#
# 有引號包住的內容，如 "Hello World!" → 字串（String）
# 沒有引號的整數，如 100 → 整數（Integer）
# 有小數點的數字，如 3.14 → 浮點數（Float）
# True、False → 布林值（Boolean）
# 提供您對 BizChat 的意見反應

# %% [markdown]
# #### 課堂練習
#
# ### 開啟偵錯主控台
# 選擇：偵錯主控台（Debug Console）或按：Ctrl + Shift + Y（在檢視的區塊），即可開啟 Python Debug Console。
# 會在畫面中央下方看到游標　＞　在游標處輸入以下：
# ### 查看變數的值
# 輸入`message`，結果：_______________，表示目前變數 `message` 的值為Hello World!
# ### 查看資料型別
# 輸入：`type(message)`，結果：___________，表示message的資料型別是字串（String）。
# ### 查看字串長度
# 輸入：`len(message)`，結果：______________，表示"Hello World!"共有 12 個字元。
# ### 呼叫字串方法
# 輸入：`message.upper()`，結果：'HELLO WORLD!'，表示字串已轉換成大寫。
# ### 修改變數
# 輸入`message = "Python"`，再次輸入message，結果'Python'，此時 Variables 視窗也會同步更新。

# %% [markdown]
# #### Print Debugging
# 在學習偵錯工具（Debugger）之前，程式設計師最常使用的除錯方法是：`print()`。例如：
# ```python
# message = "Hello World!"
# print(message)
# ```
# ```text
# Hello World!
# ```
# 藉由觀察輸出結果，我們可以確認：
# - 變數是否存在
# - 變數的值是否正確
# - 程式是否執行到某一行
# - 資料型別是否符合預期
# 這種除錯方式稱為：Print Debugging。例如：
#
# —　觀察變數：
# ```python
# message = "Hello World!"
# print(message)
# message = 100
# print(message)
# ```
# 輸出：
# ```text
# Hello World!
# 100
# ```
#
# - 觀察資料型別：
# ```python
# message = "Hello World!"
# print(type(message))
# ```
# 輸出：
# ```text
# <class 'str'>
# ‵``
# ```python
# message = 100
# print(type(message))
# ```
# 輸出：
# ```text
# <class 'int'>
# ```
#
# - 觀察程式執行流程：
# ```python
# print("Step 1")
# message = "Hello World!"
# print("Step 2")
# print(message)
# print("Step 3")
# ```
# 輸出：
# ```text
# Step 1
# Step 2
# Hello World!
# Step 3
# ```
# 這有助於確認：程式執行順序。
#
# 隨著程式越來越複雜，大量使用：`print(...)`會變得不方便。因此現代開發工具提供了大量除錯工具。
